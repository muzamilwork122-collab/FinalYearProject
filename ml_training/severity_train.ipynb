# %% [markdown]
# # Severity Classifier Training
# Train a scikit-learn classifier on extracted features to predict Low/Medium/High severity.

# %%
import numpy as np
import pickle
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
print('Libraries loaded')

# %% [markdown]
# ## 1. Load Features
# Features are extracted from segmentation + detection outputs per image.

# %%
# X = np.load('features.npy')  # shape: (N, 5)
# y = np.array(['low', 'high', 'medium', ...])  # string labels
# le = LabelEncoder()
# y_enc = le.fit_transform(y)
X, y_enc, le = None, None, None  # TODO: load your data

# %% [markdown]
# ## 2. Train & Evaluate

# %%
# clf = GradientBoostingClassifier(n_estimators=100, max_depth=4)
# scores = cross_val_score(clf, X, y_enc, cv=5, scoring='accuracy')
# print(f'CV Accuracy: {scores.mean():.3f} ± {scores.std():.3f}')
# clf.fit(X, y_enc)

# %% [markdown]
# ## 3. Save

# %%
# with open('../backend/models_weights/severity.pkl', 'wb') as f:
#     pickle.dump(clf, f)
# print('Saved severity.pkl')
