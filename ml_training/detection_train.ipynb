# %% [markdown]
# # Detection Model Training
# Fine-tune an object detection model (e.g. YOLOv8 or Faster R-CNN) to detect damage zones.

# %%
import torch
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torch.utils.data import DataLoader
print('Libraries loaded')

# %% [markdown]
# ## 1. Dataset
# Expected format: COCO JSON or YOLO TXT annotations.

# %%
# Load your dataset here
# Example: use torchvision CocoDetection or a custom Dataset class
dataset = None  # TODO

# %% [markdown]
# ## 2. Model Setup

# %%
NUM_CLASSES = 3  # background + crack + scratch
model = fasterrcnn_resnet50_fpn(pretrained=True)
in_features = model.roi_heads.box_predictor.cls_score.in_features
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, NUM_CLASSES)

# %% [markdown]
# ## 3. Training

# %%
# optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9)
# for epoch in range(EPOCHS):
#     model.train()
#     for images, targets in dataloader:
#         loss_dict = model(images, targets)
#         losses = sum(loss for loss in loss_dict.values())
#         optimizer.zero_grad()
#         losses.backward()
#         optimizer.step()

# %% [markdown]
# ## 4. Save

# %%
# torch.save(model, '../backend/models_weights/detection.pt')
# print('Saved detection.pt')
