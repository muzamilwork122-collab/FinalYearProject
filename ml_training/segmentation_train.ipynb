# %% [markdown]
# # Segmentation Model Training
# Train a U-Net style model to produce pixel-wise damage masks.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as T
from pathlib import Path
import numpy as np
from PIL import Image
print('Libraries loaded')

# %% [markdown]
# ## 1. Dataset

# %%
class DamageSegDataset(Dataset):
    def __init__(self, images_dir, masks_dir, transform=None):
        self.images = sorted(Path(images_dir).glob('*.jpg'))
        self.masks_dir = Path(masks_dir)
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        mask_path = self.masks_dir / (img_path.stem + '_mask.png')
        image = Image.open(img_path).convert('RGB').resize((224, 224))
        mask = Image.open(mask_path).convert('L').resize((224, 224))
        image = T.ToTensor()(image)
        mask = torch.from_numpy(np.array(mask) / 255.0).float()
        return image, mask.unsqueeze(0)

# %% [markdown]
# ## 2. Model

# %%
# TODO: Define U-Net or load torchvision segmentation model
# Example: model = torchvision.models.segmentation.deeplabv3_resnet50(pretrained=True)
# Adjust head for binary segmentation
model = None  # Replace with your model

# %% [markdown]
# ## 3. Training Loop

# %%
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# criterion = nn.BCEWithLogitsLoss()
# for epoch in range(EPOCHS):
#     for images, masks in train_loader:
#         optimizer.zero_grad()
#         outputs = model(images)
#         loss = criterion(outputs, masks)
#         loss.backward()
#         optimizer.step()

# %% [markdown]
# ## 4. Save Model

# %%
# torch.save(model, '../backend/models_weights/segmentation.pt')
# print('Saved segmentation.pt')
